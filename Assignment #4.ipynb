# %%
from twitterscraper import query_tweets
import pandas as pd
import numpy as np
import datetime
import time
# Out:
# INFO: {'User-Agent': 'Mozilla/5.0 (Windows; U; Windows NT 6.1; x64; fr; rv:1.9.2.13) Gecko/20101203 Firebird/3.6.13'}

# %%
#List of keywords to search for ()
kw_list = ['"ZOOM", "Zoom"']
#kw_list = ['"Corona" AND "Beer"']
begin = datetime.date(2020, 1, 1)
end = datetime.date(2020, 4, 10)
limit = 10000
lang = 'en'
poolsize = 5

# %%
if __name__ == '__main__':
    start_time = time.time()
    tweets = query_tweets(query=" OR ".join(kw_list), 
                          begindate=begin, 
                          enddate = end,
                          limit = limit,
                          lang = lang,
                          poolsize = poolsize,
                         )
print(str(len(tweets)) + " tweets scraped in " + str(round(time.time() - start_time, 2)) + " seconds")
# Out:
# INFO: queries: ['"ZOOM", "Zoom" since:2020-01-01 until:2020-01-21', '"ZOOM", "Zoom" since:2020-01-21 until:2020-02-10', '"ZOOM", "Zoom" since:2020-02-10 until:2020-03-01', '"ZOOM", "Zoom" since:2020-03-01 until:2020-03-21', '"ZOOM", "Zoom" since:2020-03-21 until:2020-04-10']
# INFO: Querying "ZOOM", "Zoom" since:2020-02-10 until:2020-03-01
# INFO: Querying "ZOOM", "Zoom" since:2020-01-01 until:2020-01-21
# INFO: Querying "ZOOM", "Zoom" since:2020-01-21 until:2020-02-10
# INFO: Querying "ZOOM", "Zoom" since:2020-03-01 until:2020-03-21
# INFO: Querying "ZOOM", "Zoom" since:2020-03-21 until:2020-04-10
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="ZOOM",%20"Zoom"%20since%3A2020-01-01%20until%3A2020-01-21&l=en
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="ZOOM",%20"Zoom"%20since%3A2020-02-10%20until%3A2020-03-01&l=en
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="ZOOM",%20"Zoom"%20since%3A2020-01-21%20until%3A2020-02-10&l=en
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="ZOOM",%20"Zoom"%20since%3A2020-03-01%20until%3A2020-03-21&l=en
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="ZOOM",%20"Zoom"%20since%3A2020-03-21%20until%3A2020-04-10&l=en
# INFO: Using proxy 27.123.255.82:30029
# INFO: Using proxy 27.123.255.82:30029
# INFO: Using proxy 27.123.255.82:30029
# INFO: Using proxy 27.123.255.82:30029
# INFO: Using proxy 27.123.255.82:30029
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1241152383591354368-1241152535114780672&q="ZOOM",%20"Zoom"%20since%3A2020-03-01%20until%3A2020-03-21&l=en
# INFO: Using proxy 118.172.51.84:58354
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1248400195802431493-1248400295807184897&q="ZOOM",%20"Zoom"%20since%3A2020-03-21%20until%3A2020-04-10&l=en
# INFO: Using proxy 118.172.51.84:58354
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1233902995273732096-1233904766767566848&q="ZOOM",%20"Zoom"%20since%3A2020-02-10%20until%3A2020-03-01&l=en
# INFO: Using proxy 118.172.51.84:58354
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1219407708559818752-1219409098007072768&q="ZOOM",%20"Zoom"%20since%3A2020-01-01%20until%3A2020-01-21&l=en
# INFO: Using proxy 118.172.51.84:58354
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1226655336494518272-1226656917428359175&q="ZOOM",%20"Zoom"%20since%3A2020-01-21%20until%3A2020-02-10&l=en
# INFO: Using proxy 118.172.51.84:58354
# ERROR: Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1248400195802431493-1248400295807184897&q="ZOOM",%20"Zoom"%20since%3A2020-03-21%20until%3A2020-04-10&l=en"
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/twitterscraper/query.py", line 99, in query_single_page
#     json_resp = response.json()
#   File "/opt/anaconda3/lib/python3.7/site-packages/requests/models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "/opt/anaconda3/lib/python3.7/json/__init__.py", line 348, in loads
#     return _default_decoder.decode(s)
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO: Retrying... (Attempts left: 50)
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1248400195802431493-1248400295807184897&q="ZOOM",%20"Zoom"%20since%3A2020-03-21%20until%3A2020-04-10&l=en
# INFO: Using proxy 178.168.67.89:4645
# ERROR: Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1233902995273732096-1233904766767566848&q="ZOOM",%20"Zoom"%20since%3A2020-02-10%20until%3A2020-03-01&l=en"
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/twitterscraper/query.py", line 99, in query_single_page
#     json_resp = response.json()
#   File "/opt/anaconda3/lib/python3.7/site-packages/requests/models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "/opt/anaconda3/lib/python3.7/json/__init__.py", line 348, in loads
#     return _default_decoder.decode(s)
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO: Retrying... (Attempts left: 50)
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1233902995273732096-1233904766767566848&q="ZOOM",%20"Zoom"%20since%3A2020-02-10%20until%3A2020-03-01&l=en
# INFO: Using proxy 178.168.67.89:4645
# ERROR: Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1226655336494518272-1226656917428359175&q="ZOOM",%20"Zoom"%20since%3A2020-01-21%20until%3A2020-02-10&l=en"
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/twitterscraper/query.py", line 99, in query_single_page
#     json_resp = response.json()
#   File "/opt/anaconda3/lib/python3.7/site-packages/requests/models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "/opt/anaconda3/lib/python3.7/json/__init__.py", line 348, in loads
#     return _default_decoder.decode(s)
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO: Retrying... (Attempts left: 50)
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1226655336494518272-1226656917428359175&q="ZOOM",%20"Zoom"%20since%3A2020-01-21%20until%3A2020-02-10&l=en
# ERROR: Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1241152383591354368-1241152535114780672&q="ZOOM",%20"Zoom"%20since%3A2020-03-01%20until%3A2020-03-21&l=en"
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/twitterscraper/query.py", line 99, in query_single_page
#     json_resp = response.json()
#   File "/opt/anaconda3/lib/python3.7/site-packages/requests/models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "/opt/anaconda3/lib/python3.7/json/__init__.py", line 348, in loads
#     return _default_decoder.decode(s)
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO: Using proxy 178.168.67.89:4645
# INFO: Retrying... (Attempts left: 50)
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1241152383591354368-1241152535114780672&q="ZOOM",%20"Zoom"%20since%3A2020-03-01%20until%3A2020-03-21&l=en
# INFO: Using proxy 178.168.67.89:4645
# ERROR: Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1248400195802431493-1248400295807184897&q="ZOOM",%20"Zoom"%20since%3A2020-03-21%20until%3A2020-04-10&l=en"
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/twitterscraper/query.py", line 99, in query_single_page
#     json_resp = response.json()
#   File "/opt/anaconda3/lib/python3.7/site-packages/requests/models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "/opt/anaconda3/lib/python3.7/json/__init__.py", line 348, in loads
#     return _default_decoder.decode(s)
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO: Retrying... (Attempts left: 49)
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1248400195802431493-1248400295807184897&q="ZOOM",%20"Zoom"%20since%3A2020-03-21%20until%3A2020-04-10&l=en
# INFO: Using proxy 201.151.79.30:8080
# ERROR: Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1219407708559818752-1219409098007072768&q="ZOOM",%20"Zoom"%20since%3A2020-01-01%20until%3A2020-01-21&l=en"
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/twitterscraper/query.py", line 99, in query_single_page
#     json_resp = response.json()
#   File "/opt/anaconda3/lib/python3.7/site-packages/requests/models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "/opt/anaconda3/lib/python3.7/json/__init__.py", line 348, in loads
#     return _default_decoder.decode(s)
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO: Retrying... (Attempts left: 50)
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1219407708559818752-1219409098007072768&q="ZOOM",%20"Zoom"%20since%3A2020-01-01%20until%3A2020-01-21&l=en
# INFO: Using proxy 178.168.67.89:4645
# ERROR: Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1233902995273732096-1233904766767566848&q="ZOOM",%20"Zoom"%20since%3A2020-02-10%20until%3A2020-03-01&l=en"
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/twitterscraper/query.py", line 99, in query_single_page
#     json_resp = response.json()
#   File "/opt/anaconda3/lib/python3.7/site-packages/requests/models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "/opt/anaconda3/lib/python3.7/json/__init__.py", line 348, in loads
#     return _default_decoder.decode(s)
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO: Retrying... (Attempts left: 49)
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1233902995273732096-1233904766767566848&q="ZOOM",%20"Zoom"%20since%3A2020-02-10%20until%3A2020-03-01&l=en
# INFO: Using proxy 201.151.79.30:8080
# ERROR: Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1226655336494518272-1226656917428359175&q="ZOOM",%20"Zoom"%20since%3A2020-01-21%20until%3A2020-02-10&l=en"
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/twitterscraper/query.py", line 99, in query_single_page
#     json_resp = response.json()
#   File "/opt/anaconda3/lib/python3.7/site-packages/requests/models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "/opt/anaconda3/lib/python3.7/json/__init__.py", line 348, in loads
#     return _default_decoder.decode(s)
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO: Retrying... (Attempts left: 49)
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1226655336494518272-1226656917428359175&q="ZOOM",%20"Zoom"%20since%3A2020-01-21%20until%3A2020-02-10&l=en
# INFO: Using proxy 201.151.79.30:8080
# ERROR: Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1241152383591354368-1241152535114780672&q="ZOOM",%20"Zoom"%20since%3A2020-03-01%20until%3A2020-03-21&l=en"
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/twitterscraper/query.py", line 99, in query_single_page
#     json_resp = response.json()
#   File "/opt/anaconda3/lib/python3.7/site-packages/requests/models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "/opt/anaconda3/lib/python3.7/json/__init__.py", line 348, in loads
#     return _default_decoder.decode(s)
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO: Retrying... (Attempts left: 49)
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1241152383591354368-1241152535114780672&q="ZOOM",%20"Zoom"%20since%3A2020-03-01%20until%3A2020-03-21&l=en
# INFO: Using proxy 201.151.79.30:8080
# ERROR: Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1248400195802431493-1248400295807184897&q="ZOOM",%20"Zoom"%20since%3A2020-03-21%20until%3A2020-04-10&l=en"
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/twitterscraper/query.py", line 99, in query_single_page
#     json_resp = response.json()
#   File "/opt/anaconda3/lib/python3.7/site-packages/requests/models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "/opt/anaconda3/lib/python3.7/json/__init__.py", line 348, in loads
#     return _default_decoder.decode(s)
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO: Retrying... (Attempts left: 48)
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1248400195802431493-1248400295807184897&q="ZOOM",%20"Zoom"%20since%3A2020-03-21%20until%3A2020-04-10&l=en
# INFO: Using proxy 103.31.227.27:8080
# ERROR: Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1219407708559818752-1219409098007072768&q="ZOOM",%20"Zoom"%20since%3A2020-01-01%20until%3A2020-01-21&l=en"
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/twitterscraper/query.py", line 99, in query_single_page
#     json_resp = response.json()
#   File "/opt/anaconda3/lib/python3.7/site-packages/requests/models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "/opt/anaconda3/lib/python3.7/json/__init__.py", line 348, in loads
#     return _default_decoder.decode(s)
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO: Retrying... (Attempts left: 49)
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1219407708559818752-1219409098007072768&q="ZOOM",%20"Zoom"%20since%3A2020-01-01%20until%3A2020-01-21&l=en
# INFO: Using proxy 201.151.79.30:8080
# ERROR: Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1233902995273732096-1233904766767566848&q="ZOOM",%20"Zoom"%20since%3A2020-02-10%20until%3A2020-03-01&l=en"
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/twitterscraper/query.py", line 99, in query_single_page
#     json_resp = response.json()
#   File "/opt/anaconda3/lib/python3.7/site-packages/requests/models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "/opt/anaconda3/lib/python3.7/json/__init__.py", line 348, in loads
#     return _default_decoder.decode(s)
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO: Retrying... (Attempts left: 48)
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1233902995273732096-1233904766767566848&q="ZOOM",%20"Zoom"%20since%3A2020-02-10%20until%3A2020-03-01&l=en
# INFO: Using proxy 103.31.227.27:8080
# ERROR: Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1226655336494518272-1226656917428359175&q="ZOOM",%20"Zoom"%20since%3A2020-01-21%20until%3A2020-02-10&l=en"
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/twitterscraper/query.py", line 99, in query_single_page
#     json_resp = response.json()
#   File "/opt/anaconda3/lib/python3.7/site-packages/requests/models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "/opt/anaconda3/lib/python3.7/json/__init__.py", line 348, in loads
#     return _default_decoder.decode(s)
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO: Retrying... (Attempts left: 48)
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1226655336494518272-1226656917428359175&q="ZOOM",%20"Zoom"%20since%3A2020-01-21%20until%3A2020-02-10&l=en
# INFO: Using proxy 103.31.227.27:8080
# ERROR: Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1248400195802431493-1248400295807184897&q="ZOOM",%20"Zoom"%20since%3A2020-03-21%20until%3A2020-04-10&l=en"
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/twitterscraper/query.py", line 99, in query_single_page
#     json_resp = response.json()
#   File "/opt/anaconda3/lib/python3.7/site-packages/requests/models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "/opt/anaconda3/lib/python3.7/json/__init__.py", line 348, in loads
#     return _default_decoder.decode(s)
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO: Retrying... (Attempts left: 47)
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1248400195802431493-1248400295807184897&q="ZOOM",%20"Zoom"%20since%3A2020-03-21%20until%3A2020-04-10&l=en
# INFO: Using proxy 185.49.130.81:48377
# ERROR: Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1219407708559818752-1219409098007072768&q="ZOOM",%20"Zoom"%20since%3A2020-01-01%20until%3A2020-01-21&l=en"
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/twitterscraper/query.py", line 99, in query_single_page
#     json_resp = response.json()
#   File "/opt/anaconda3/lib/python3.7/site-packages/requests/models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "/opt/anaconda3/lib/python3.7/json/__init__.py", line 348, in loads
#     return _default_decoder.decode(s)
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO: Retrying... (Attempts left: 48)
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1219407708559818752-1219409098007072768&q="ZOOM",%20"Zoom"%20since%3A2020-01-01%20until%3A2020-01-21&l=en
# INFO: Using proxy 103.31.227.27:8080
# ERROR: Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1233902995273732096-1233904766767566848&q="ZOOM",%20"Zoom"%20since%3A2020-02-10%20until%3A2020-03-01&l=en"
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/twitterscraper/query.py", line 99, in query_single_page
#     json_resp = response.json()
#   File "/opt/anaconda3/lib/python3.7/site-packages/requests/models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "/opt/anaconda3/lib/python3.7/json/__init__.py", line 348, in loads
#     return _default_decoder.decode(s)
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO: Retrying... (Attempts left: 47)
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1233902995273732096-1233904766767566848&q="ZOOM",%20"Zoom"%20since%3A2020-02-10%20until%3A2020-03-01&l=en
# INFO: Using proxy 185.49.130.81:48377
# ERROR: Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1226655336494518272-1226656917428359175&q="ZOOM",%20"Zoom"%20since%3A2020-01-21%20until%3A2020-02-10&l=en"
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/twitterscraper/query.py", line 99, in query_single_page
#     json_resp = response.json()
#   File "/opt/anaconda3/lib/python3.7/site-packages/requests/models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "/opt/anaconda3/lib/python3.7/json/__init__.py", line 348, in loads
#     return _default_decoder.decode(s)
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO: Retrying... (Attempts left: 47)
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1226655336494518272-1226656917428359175&q="ZOOM",%20"Zoom"%20since%3A2020-01-21%20until%3A2020-02-10&l=en
# INFO: Using proxy 185.49.130.81:48377
# ERROR: Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1241152383591354368-1241152535114780672&q="ZOOM",%20"Zoom"%20since%3A2020-03-01%20until%3A2020-03-21&l=en"
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/twitterscraper/query.py", line 99, in query_single_page
#     json_resp = response.json()
#   File "/opt/anaconda3/lib/python3.7/site-packages/requests/models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "/opt/anaconda3/lib/python3.7/json/__init__.py", line 348, in loads
#     return _default_decoder.decode(s)
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO: Retrying... (Attempts left: 48)
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1241152383591354368-1241152535114780672&q="ZOOM",%20"Zoom"%20since%3A2020-03-01%20until%3A2020-03-21&l=en
# INFO: Using proxy 103.31.227.27:8080
# ERROR: Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1248400195802431493-1248400295807184897&q="ZOOM",%20"Zoom"%20since%3A2020-03-21%20until%3A2020-04-10&l=en"
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/twitterscraper/query.py", line 99, in query_single_page
#     json_resp = response.json()
#   File "/opt/anaconda3/lib/python3.7/site-packages/requests/models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "/opt/anaconda3/lib/python3.7/json/__init__.py", line 348, in loads
#     return _default_decoder.decode(s)
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO: Retrying... (Attempts left: 46)
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1248400195802431493-1248400295807184897&q="ZOOM",%20"Zoom"%20since%3A2020-03-21%20until%3A2020-04-10&l=en
# INFO: Using proxy 36.89.182.85:51387
# ERROR: Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1219407708559818752-1219409098007072768&q="ZOOM",%20"Zoom"%20since%3A2020-01-01%20until%3A2020-01-21&l=en"
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/twitterscraper/query.py", line 99, in query_single_page
#     json_resp = response.json()
#   File "/opt/anaconda3/lib/python3.7/site-packages/requests/models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "/opt/anaconda3/lib/python3.7/json/__init__.py", line 348, in loads
#     return _default_decoder.decode(s)
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO: Retrying... (Attempts left: 47)
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1219407708559818752-1219409098007072768&q="ZOOM",%20"Zoom"%20since%3A2020-01-01%20until%3A2020-01-21&l=en
# INFO: Using proxy 185.49.130.81:48377
# ERROR: Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1233902995273732096-1233904766767566848&q="ZOOM",%20"Zoom"%20since%3A2020-02-10%20until%3A2020-03-01&l=en"
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/twitterscraper/query.py", line 99, in query_single_page
#     json_resp = response.json()
#   File "/opt/anaconda3/lib/python3.7/site-packages/requests/models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "/opt/anaconda3/lib/python3.7/json/__init__.py", line 348, in loads
#     return _default_decoder.decode(s)
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO: Retrying... (Attempts left: 46)
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1233902995273732096-1233904766767566848&q="ZOOM",%20"Zoom"%20since%3A2020-02-10%20until%3A2020-03-01&l=en
# INFO: Using proxy 36.89.182.85:51387
# ERROR: Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1241152383591354368-1241152535114780672&q="ZOOM",%20"Zoom"%20since%3A2020-03-01%20until%3A2020-03-21&l=en"
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/twitterscraper/query.py", line 99, in query_single_page
#     json_resp = response.json()
#   File "/opt/anaconda3/lib/python3.7/site-packages/requests/models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "/opt/anaconda3/lib/python3.7/json/__init__.py", line 348, in loads
#     return _default_decoder.decode(s)
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO: Retrying... (Attempts left: 47)
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1241152383591354368-1241152535114780672&q="ZOOM",%20"Zoom"%20since%3A2020-03-01%20until%3A2020-03-21&l=en
# INFO: Using proxy 185.49.130.81:48377
# ERROR: Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1226655336494518272-1226656917428359175&q="ZOOM",%20"Zoom"%20since%3A2020-01-21%20until%3A2020-02-10&l=en"
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/twitterscraper/query.py", line 99, in query_single_page
#     json_resp = response.json()
#   File "/opt/anaconda3/lib/python3.7/site-packages/requests/models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "/opt/anaconda3/lib/python3.7/json/__init__.py", line 348, in loads
#     return _default_decoder.decode(s)
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO: Retrying... (Attempts left: 46)
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1226655336494518272-1226656917428359175&q="ZOOM",%20"Zoom"%20since%3A2020-01-21%20until%3A2020-02-10&l=en
# INFO: Using proxy 36.89.182.85:51387
# ERROR: Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1248400195802431493-1248400295807184897&q="ZOOM",%20"Zoom"%20since%3A2020-03-21%20until%3A2020-04-10&l=en"
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/twitterscraper/query.py", line 99, in query_single_page
#     json_resp = response.json()
#   File "/opt/anaconda3/lib/python3.7/site-packages/requests/models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "/opt/anaconda3/lib/python3.7/json/__init__.py", line 348, in loads
#     return _default_decoder.decode(s)
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO: Retrying... (Attempts left: 45)
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1248400195802431493-1248400295807184897&q="ZOOM",%20"Zoom"%20since%3A2020-03-21%20until%3A2020-04-10&l=en
# INFO: Using proxy 81.161.61.88:31692
# ERROR: Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1219407708559818752-1219409098007072768&q="ZOOM",%20"Zoom"%20since%3A2020-01-01%20until%3A2020-01-21&l=en"
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/twitterscraper/query.py", line 99, in query_single_page
#     json_resp = response.json()
#   File "/opt/anaconda3/lib/python3.7/site-packages/requests/models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "/opt/anaconda3/lib/python3.7/json/__init__.py", line 348, in loads
#     return _default_decoder.decode(s)
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO: Retrying... (Attempts left: 46)
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1219407708559818752-1219409098007072768&q="ZOOM",%20"Zoom"%20since%3A2020-01-01%20until%3A2020-01-21&l=en
# INFO: Using proxy 36.89.182.85:51387
# ERROR: Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1233902995273732096-1233904766767566848&q="ZOOM",%20"Zoom"%20since%3A2020-02-10%20until%3A2020-03-01&l=en"
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/twitterscraper/query.py", line 99, in query_single_page
#     json_resp = response.json()
#   File "/opt/anaconda3/lib/python3.7/site-packages/requests/models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "/opt/anaconda3/lib/python3.7/json/__init__.py", line 348, in loads
#     return _default_decoder.decode(s)
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO: Retrying... (Attempts left: 45)
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1233902995273732096-1233904766767566848&q="ZOOM",%20"Zoom"%20since%3A2020-02-10%20until%3A2020-03-01&l=en
# INFO: Using proxy 81.161.61.88:31692
# ERROR: Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1226655336494518272-1226656917428359175&q="ZOOM",%20"Zoom"%20since%3A2020-01-21%20until%3A2020-02-10&l=en"
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/twitterscraper/query.py", line 99, in query_single_page
#     json_resp = response.json()
#   File "/opt/anaconda3/lib/python3.7/site-packages/requests/models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "/opt/anaconda3/lib/python3.7/json/__init__.py", line 348, in loads
#     return _default_decoder.decode(s)
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO: Retrying... (Attempts left: 45)
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1226655336494518272-1226656917428359175&q="ZOOM",%20"Zoom"%20since%3A2020-01-21%20until%3A2020-02-10&l=en
# INFO: Using proxy 81.161.61.88:31692
# ERROR: Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1248400195802431493-1248400295807184897&q="ZOOM",%20"Zoom"%20since%3A2020-03-21%20until%3A2020-04-10&l=en"
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/twitterscraper/query.py", line 99, in query_single_page
#     json_resp = response.json()
#   File "/opt/anaconda3/lib/python3.7/site-packages/requests/models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "/opt/anaconda3/lib/python3.7/json/__init__.py", line 348, in loads
#     return _default_decoder.decode(s)
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO: Retrying... (Attempts left: 44)
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1248400195802431493-1248400295807184897&q="ZOOM",%20"Zoom"%20since%3A2020-03-21%20until%3A2020-04-10&l=en
# INFO: Using proxy 5.58.85.32:38022
# ERROR: Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1219407708559818752-1219409098007072768&q="ZOOM",%20"Zoom"%20since%3A2020-01-01%20until%3A2020-01-21&l=en"
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/twitterscraper/query.py", line 99, in query_single_page
#     json_resp = response.json()
#   File "/opt/anaconda3/lib/python3.7/site-packages/requests/models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "/opt/anaconda3/lib/python3.7/json/__init__.py", line 348, in loads
#     return _default_decoder.decode(s)
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/opt/anaconda3/lib/python3.7/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO: Retrying... (Attempts left: 45)
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1219407708559818752-1219409098007072768&q="ZOOM",%20"Zoom"%20since%3A2020-01-01%20until%3A2020-01-21&l=en
# INFO: Using proxy 81.161.61.88:31692
# ERROR: Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1233902995273732096-1233904766767566848&q="ZOOM",%20"Zoom"%20since%3A2020-02-10%20until%3A2020-03-01&l=en"
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/twitterscraper/query.py", line 99, in query_single_page
#     json_resp = response.json()
#   File "/opt/anaconda3/lib/python3.7/site-packages/requests/models.py", line 897, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "
ZOOM",%20"Zoom"%20since%3A2020-02-10%20until%3A2020-03-01&l=en
# INFO: Using proxy 103.211.76.5:8080
# INFO: Got 2003 tweets for "ZOOM",%20"Zoom"%20since%3A2020-01-21%20until%3A2020-02-10.
# INFO: Got 8027 tweets (2003 new).
# INFO: Got 2011 tweets for "ZOOM",%20"Zoom"%20since%3A2020-02-10%20until%3A2020-03-01.
# INFO: Got 10038 tweets (2011 new).
# 10038 tweets scraped in 154.1 seconds

# %%
tweets_df = pd.DataFrame(columns = ['timestamp', 'username',  'screen_name', 'user_id','tweet_id', 
                                    'text', 'likes', 'replies', 'retweets','tweet_url', 'parent_tweet_id'])

# %%
for tweet in tweets:
    tweets_df = tweets_df.append({
        'timestamp': tweet.timestamp,
        'username': tweet.username,
        'screen_name': tweet.screen_name,
        'user_id': tweet.user_id,
        'tweet_id': tweet.tweet_id,
        'text': tweet.text,
        'likes': tweet.likes,
        'replies': tweet.replies,
        'retweets' : tweet.retweets,
        'tweet_url': tweet.tweet_url,
        'parent_tweet_id': tweet.parent_tweet_id}, ignore_index=True)
        #,'has_media': tweet.has_media,'hashtags': tweet.hashtags,'img_urls': tweet.img_urls,'is_replied': tweet.is_replied, 'is_reply_to': tweet.is_reply_to, 'links': tweet.links,'reply_to_users': tweet.reply_to_users, 'video_url': tweet.video_url}, ignore_index=True)

# Delete the tweet object from memory
import gc
del tweets
gc.collect()
# Out:
# 0

# %%
from twitterscraper import query_tweets
#List of keywords to search for ()
kw_list = ['"ZOOM", "zoom"']
#kw_list = ['"Corona" AND "Beer"']
begin = datetime.date(2019, 9, 1)
end = datetime.date(2019, 12, 31)
limit = 10000
lang = 'en'
poolsize = 5

# Start the Scraper
if __name__ == '__main__':
    start_time = time.time()
    tweets = query_tweets(query=" OR ".join(kw_list), 
                          begindate=begin, 
                          enddate = end,
                          limit = limit,
                          lang = lang,
                          poolsize = poolsize,
                         )
display(str(len(tweets)) + " tweets scraped in " + str(round(time.time() - start_time, 2)) + " seconds")

# Define a dataframe
tweets_df2 = pd.DataFrame(columns = ['timestamp', 'username',  'screen_name', 'user_id','tweet_id', 
                                    'text', 'likes', 'replies', 'retweets','tweet_url', 'parent_tweet_id'])
                         #,'has_media', 'hashtags', 'img_urls', 'is_replied','is_reply_to', 'links','reply_to_users', 'video_url']) 
    
# populate the dataframe    
for tweet in tweets:
    tweets_df2 = tweets_df2.append({
        'timestamp': tweet.timestamp,
        'username': tweet.username,
        'screen_name': tweet.screen_name,
        'user_id': tweet.user_id,
        'tweet_id': tweet.tweet_id,
        'text': tweet.text,
        'likes': tweet.likes,
        'replies': tweet.replies,
        'retweets' : tweet.retweets,
        'tweet_url': tweet.tweet_url,
        'parent_tweet_id': tweet.parent_tweet_id}, ignore_index=True)
        #,'has_media': tweet.has_media,'hashtags': tweet.hashtags,'img_urls': tweet.img_urls,'is_replied': tweet.is_replied, 'is_reply_to': tweet.is_reply_to, 'links': tweet.links,'reply_to_users': tweet.reply_to_users, 'video_url': tweet.video_url}, ignore_index=True)

# Delete the tweet object from memory
import gc
del tweets
CEWjoC2gYK2ltEhEjUAFQAlAFUAFQAA&q="ZOOM",%20"zoom"%20since%3A2019-12-06%20until%3A2019-12-31&l=en
# INFO: Using proxy 41.60.235.62:8080
# INFO: Got 4017 tweets (2006 new).
# INFO: Got 2008 tweets for "ZOOM",%20"zoom"%20since%3A2019-09-01%20until%3A2019-09-25.
# INFO: Got 6025 tweets (2008 new).
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgLX1iMmjsCEWgMC8yZzF_rAhEjUAFQAlAFUAFQAA&q="ZOOM",%20"zoom"%20since%3A2019-11-12%20until%3A2019-12-06&l=en
# INFO: Using proxy 41.60.235.62:8080
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaEwLz1jKCt0CEWjoC2gYK2ltEhEjUAFQAlAFUAFQAA&q="ZOOM",%20"zoom"%20since%3A2019-12-06%20until%3A2019-12-31&l=en
# INFO: Using proxy 146.0.109.15:8080
# INFO: Got 2010 tweets for "ZOOM",%20"zoom"%20since%3A2019-11-12%20until%3A2019-12-06.
# INFO: Got 8035 tweets (2010 new).
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgKah2Z6s0CEWjoC2gYK2ltEhEjUAFQAlAFUAFQAA&q="ZOOM",%20"zoom"%20since%3A2019-12-06%20until%3A2019-12-31&l=en
# INFO: Using proxy 177.41.0.30:20183
# INFO: Got 2006 tweets for "ZOOM",%20"zoom"%20since%3A2019-12-06%20until%3A2019-12-31.
# INFO: Got 10041 tweets (2006 new).
# '10041 tweets scraped in 126.54 seconds'
# 0

# %%
# Now append the second dataframe to the first one
tweets_df=tweets_df.append(tweets_df2, ignore_index = True)
# Reset index
#tweets_df.reset_index(inplace = True) 
# Check if it worked!
tweets_df.shape
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
# (20072, 14)

# %%
# for i in range(0,12):
#     print(tweets_df.text[i]) 
#     print('\n')

# %%
# Import the module you need
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# Instantiate the sentiment analyzer
analyser = SentimentIntensityAnalyzer()

# %%
# Define a function that returns the polarity score of a sentence
def sentiment_analyzer_scores(sentence):
    score = analyser.polarity_scores(sentence)
    print("{:-<55} {}".format(sentence, str(score)), "\n")

# %%
# Test how well Vader does
my_tweet = "My zoom call was hacked yesteday"
sentiment_analyzer_scores(my_tweet)


# Print the individual polarity scores
sentiment_dict = analyser.polarity_scores(my_tweet) 
print("Compound sentiment is", sentiment_dict['compound'], "\n") 
print("Sentence was rated as", sentiment_dict['neg']*100, "% Negative") 
print("Sentence was rated as", sentiment_dict['neu']*100, "% Neutral") 
print("Sentence was rated as", sentiment_dict['pos']*100, "% Positive")
# Out:
# My zoom call was hacked yesteday----------------------- {'neg': 0.351, 'neu': 0.649, 'pos': 0.0, 'compound': -0.4019}
#
# Compound sentiment is -0.4019
#
# Sentence was rated as 35.099999999999994 % Negative
# Sentence was rated as 64.9 % Neutral
# Sentence was rated as 0.0 % Positive

# %%
# import regular expressions
import re

# Set-up patterns to be removed fro the tweets
pat1 = r"http\S+"
pat2 = r"#"
pat3 = r"@"
pat4 = r"FAV"
pat5 = r"RE"
pat6 = r"pic.\S+"
combined_pat = r'|'.join((pat1, pat2, pat3, pat4, pat5, pat6))

# replace the patterns with an empty string
tweets_df['stripped'] =  [re.sub(combined_pat, '', w) for w in tweets_df.text]

# might have double spaces now (because of empty string replacements above) - remove double empty spaces
tweets_df['stripped']  = [re.sub(r"  ", ' ', w) for w in tweets_df.loc[:,'stripped']]

# Print tweets
for i in range(0,12):
    print(tweets_df.stripped[i])
    print('\n')
# Out:
# As crazy as it sounds, we miss you!
# ‼️Coach Spencer and I (Coach K) would LOVE to zoom with y’all ‼️
# Please respond to the poll for next Tuesday and then DM this Twitter so that we can give you the password! RT this so we can say hello to as many Viking Athletes as possible
#
#
# 2 shots of Henny before my zoom presentation lmao
#
#
# Unfortunately I'm old enough to remember that show & yes I watched it. Along with Sesame ST. the original Electric CO. all on PBS. Damn I'm old! I use Zoom the video app now with friends and family that don't have Face Time I never had a issue with Zoom works great!
#
#
# I nicknamed myself Carole Baskin in my class’ Kahoot game and I’ve never been so motivated to be on the podium
#
# I’m fucking wheezing here on zoom
#
#
# My dumbass was getting ready for this zoom meeting yet i just realized we on spring break
#
#
# We’ll “zoom” you in next time!!! 💚💛
#
#
# The Crazy Prospector and Rowdy were both on a ZOOM conference. Good. Lord. gordonkeith
#
#
# I was in a church zoom call with 67 people last night and I still haven't recovered.
#
#
# it’s so great to see the security community come together in these trying times to help secure zoom. looking at you alexstamos and k8em0!
#
#
# You find out a lot about a person just by their zoom background. Hear me out:
#
# 1) Mostly forehead and plain white wall = I’ve gained 10 lbs and I can’t show you anything below the neck.
#
# 2) Beach background = I’m a antivaxxer and I grow my own arugula.
#
# (1 of 2)
#
#
# Are we allowed to do taraweeh prayers via zoom? 😅😭
#
#
# I heard of a county govt Zoom meetg. It was hacked by teenagers flashing their rear ends and showing some porn movies. Good luck w your dog.  …

# %%
# Import the sentiment module (if you haven't already done so)
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# Import numpy (if you have not already done so)
import numpy as np

# Now get the compound sentiment score for each tweet
tweets_df['C_Score'] = np.nan

for index, row in tweets_df.iterrows(): 
    tweets_df.loc[index, 'C_Score'] = analyser.polarity_scores(row['stripped'])['compound']
    
    
# Let's take a look!
pd.set_option('display.max_colwidth', -1)
tweets_df[['stripped','C_Score']].head(-50)
# Out:
#                                                                                                                                                                                                                                                                                     stripped  \
# 0      As crazy as it sounds, we miss you! \n‼️Coach Spencer and I (Coach K) would LOVE to zoom with y’all ‼️\nPlease respond to the poll for next Tuesday and then DM this Twitter so that we can give you the password! RT this so we can say hello to as many Viking Athletes as possible
# 1      2 shots of Henny before my zoom presentation lmao
# 2      Unfortunately I'm old enough to remember that show & yes I watched it. Along with Sesame ST. the original Electric CO. all on PBS. Damn I'm old! I use Zoom the video app now with friends and family that don't have Face Time I never had a issue with Zoom works great!
# 3      I nicknamed myself Carole Baskin in my class’ Kahoot game and I’ve never been so motivated to be on the podium \n\nI’m fucking wheezing here on zoom
# 4      My dumbass was getting ready for this zoom meeting yet i just realized we on spring break
# ...                                                                                          ...
# 20017  Hi Matt, do you think if they need to draw lines on a computer and zoom in is clear and obvious. I like VAR but it’s should be used for clear mistakes (like the Watford handball or Gabbis cup final goal)
# 20018  Steve took a mirror
# 20019  we're the same tho! the paper maybe contain a very important answer to us! hope i can zoom more but i cant😪
# 20020  Oppo reno 10x zoom fc Barcelona edition? Wait...
# 20021  Now Playing: "What A Feeling" By: "Irene Cara"\nListen live:\n \nOr:  …\nE: studiozoom80s.xyz\nWeb:
#
#        C_Score
# 0      0.7019
# 1      0.5994
# 2      0.8264
# 3      0.5949
# 4     -0.2732
# ...       ...
# 20017  0.7140
# 20018  0.0000
# 20019  0.4732
# 20020  0.0000
# 20021  0.3182
#
# [20022 rows x 2 columns]

# %%
#changing the timestamps on each tweet to "year-month-day"
tweets_df['timestamp'] = tweets_df['timestamp'].map(lambda x: x.strftime('%Y-%m-%d'))
tweets_df['timestamp']
# Out:
# 0        2020-04-09
# 1        2020-04-09
# 2        2020-04-09
# 3        2020-04-09
# 4        2020-04-09
#             ...
# 20067    2019-12-30
# 20068    2019-12-30
# 20069    2019-12-30
# 20070    2019-12-30
# 20071    2019-12-30
# Name: timestamp, Length: 20072, dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-13d9dbdfd27e> in <module>
# ----> 1 tweets_df.loc[0].timestamp.dtype
#
# AttributeError: 'str' object has no attribute 'dtype'

# %%
count = 0;
j = 0
for index, row in tweets_df.iterrows():
    date = row.timestamp[0:4]
    if(date == '2020'):
        count +=1
    else:
        j += 1
    
    
    
print(count)
# Out:
# 10031

# %%
print(f"Count positive tweets: {sum(tweets_df['C_Score'] > 0.05)}")
print(f"Count netural tweets: {tweets_df['C_Score'].between(-0.05, 0.05).sum()}")
print(f"Count negative tweets: {sum(tweets_df['C_Score'] < -0.05)}")
print(f"Total number of tweets: {tweets_df['C_Score'].count()}")
      
display(tweets_df.C_Score.describe())
# Out:
# Count positive tweets: 9893
# Count netural tweets: 6815
# Count negative tweets: 3364
# Total number of tweets: 20072
# count    20072.000000
# mean     0.202075
# std      0.429798
# min     -0.987900
# 25%      0.000000
# 50%      0.000000
# 75%      0.571900
# max      0.996000
# Name: C_Score, dtype: float64

# %%
# import necessary modules (if not already imported)
import matplotlib.pyplot as plt
import seaborn as sns

# settings for seaborn plotting style
sns.set(color_codes=True)

# settings for seaborn plot sizes
sns.set(rc={'figure.figsize':(10,5)})

# Create Histogram
ax = sns.distplot(tweets_df['C_Score'],
                  bins=20,
                  kde=False,
                  color='skyblue',
                  hist_kws={"linewidth": 5,'alpha':1})
ax.set(xlabel='Sentiment Distribution', ylabel='Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Sentiment Distribution')]

# %%
# create new column
tweets_df['Sentiment'] = np.nan

# Loop through rows of dataframe and determine strings for new column "Sentiment"
for index, row in tweets_df.iterrows(): 
    if tweets_df.loc[index, 'C_Score'] > 0.05 : 
            tweets_df.loc[index, 'Sentiment'] = "Positive"       
    elif tweets_df.loc[index, 'C_Score'] < -0.05 :
            tweets_df.loc[index, 'Sentiment'] = "Negative"   
    else : 
        tweets_df.loc[index, 'Sentiment'] = "Neutral"
        
tweets_df[['stripped','C_Score', 'Sentiment']].head(25)
# Out:
#                                                                                                                                                                                                                                                                                  stripped  \
# 0   As crazy as it sounds, we miss you! \n‼️Coach Spencer and I (Coach K) would LOVE to zoom with y’all ‼️\nPlease respond to the poll for next Tuesday and then DM this Twitter so that we can give you the password! RT this so we can say hello to as many Viking Athletes as possible
# 1   2 shots of Henny before my zoom presentation lmao
# 2   Unfortunately I'm old enough to remember that show & yes I watched it. Along with Sesame ST. the original Electric CO. all on PBS. Damn I'm old! I use Zoom the video app now with friends and family that don't have Face Time I never had a issue with Zoom works great!
# 3   I nicknamed myself Carole Baskin in my class’ Kahoot game and I’ve never been so motivated to be on the podium \n\nI’m fucking wheezing here on zoom
# 4   My dumbass was getting ready for this zoom meeting yet i just realized we on spring break
# 5   We’ll “zoom” you in next time!!! 💚💛
# 6   The Crazy Prospector and Rowdy were both on a ZOOM conference. Good. Lord. gordonkeith
# 7   I was in a church zoom call with 67 people last night and I still haven't recovered.
# 8   it’s so great to see the security community come together in these trying times to help secure zoom. looking at you alexstamos and k8em0!
# 9   You find out a lot about a person just by their zoom background. Hear me out: \n\n1) Mostly forehead and plain white wall = I’ve gained 10 lbs and I can’t show you anything below the neck. \n\n2) Beach background = I’m a antivaxxer and I grow my own arugula. \n\n(1 of 2)
# 10  Are we allowed to do taraweeh prayers via zoom? 😅😭
# 11  I heard of a county govt Zoom meetg. It was hacked by teenagers flashing their rear ends and showing some porn movies. Good luck w your dog.  …
# 12  I Zoom myself.. you guys are soooo behind
# 13  Zoom stock plummet will be crazy to watch
# 14  I wish I was back in class. I have a few students in my mind where I would love to see this in action. Maybe a zoom?🤷‍♀️
# 15  New quarantine goal: The first oral history done entirely via Zoom.  …
# 16  luka sabbat was rlly trolling profs in random zoom classes 😹😭 i would die from an orgasm
# 17  We will teach in Google Classroom. \nWe will teach with Loom. \nBut we will celebrate Spring Break with Happy Hour in Zoom! 🍷💕🍹 JamesburgProud KrisDeFazio LynnZinser_5 ReneeSc64409721 diana_sanger misscorribee Sra_Williamsjfk
# 18  someone just yelled nigger during my zoom lecture, SAY IT TO MY FACE PUSSY i was ready to deck a bitch
# 19  As crazy as it sounds, we miss you! \n‼️Coach Spencer and I (Coach K) would LOVE to zoom with y’all ‼️\nPlease respond to the poll for next Tuesday and then DM this Twitter so that we can give you the password! RT this so we can say hello to as many Viking Athletes as possible
# 20  2 shots of Henny before my zoom presentation lmao
# 21  Unfortunately I'm old enough to remember that show & yes I watched it. Along with Sesame ST. the original Electric CO. all on PBS. Damn I'm old! I use Zoom the video app now with friends and family that don't have Face Time I never had a issue with Zoom works great!
# 22  I nicknamed myself Carole Baskin in my class’ Kahoot game and I’ve never been so motivated to be on the podium \n\nI’m fucking wheezing here on zoom
# 23  My dumbass was getting ready for this zoom meeting yet i just realized we on spring break
# 24  We’ll “zoom” you in next time!!! 💚💛
#
#     C_Score Sentiment
# 0   0.7019   Positive
# 1   0.5994   Positive
# 2   0.8264   Positive
# 3   0.5949   Positive
# 4  -0.2732   Negative
# 5   0.0000   Neutral
# 6   0.1280   Positive
# 7   0.0000   Neutral
# 8   0.9039   Positive
# 9   0.3818   Positive
# 10 -0.1531   Negative
# 11  0.4939   Positive
# 12  0.0000   Neutral
# 13 -0.3400   Negative
# 14  0.7845   Positive
# 15  0.0000   Neutral
# 16 -0.6249   Negative
# 17  0.8988   Positive
# 18 -0.7650   Negative
# 19  0.7019   Positive
# 20  0.5994   Positive
# 21  0.8264   Positive
# 22  0.5949   Positive
# 23 -0.2732   Negative
# 24  0.0000   Neutral
